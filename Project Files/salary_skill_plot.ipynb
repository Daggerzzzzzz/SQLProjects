# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('most_optimal_skill.csv')

# %%
df.head()
# Out:
#       SKILL  DEMAND_COUNT  AVERAGE_SALARY
# 0    sheets             1          111175
# 1  bigquery             1          111175
# 2      flow             1          111175
# 3      zoom             1          111175
# 4         c             1          111175

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SKILL           25 non-null     object
#  1   DEMAND_COUNT    25 non-null     int64
#  2   AVERAGE_SALARY  25 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 728.0+ bytes

# %%
df = df.sort_values(by='AVERAGE_SALARY', ascending=False)

# %%
bar_plot = sns.barplot(x='AVERAGE_SALARY', y='SKILL', hue='DEMAND_COUNT',  data=df)

# %%
bar_plot.figure.savefig("hist_plot.png", dpi=300, bbox_inches="tight")
